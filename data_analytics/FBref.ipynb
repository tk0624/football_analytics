# %%
import pandas as pd
pd.set_option('display.max_rows', 20)
import time
import ftfy

# %% [markdown]
# # 関連ファイル読み込み

# %%
df_map['PlayerFBref'] = df_map['PlayerFBref'].apply(ftfy.fix_text)

# %%
df_map.to_csv('fbref_to_tm_mapping.csv', index=None)

# %%
df_map = pd.read_csv('fbref_to_tm_mapping.csv', encoding="latin1")
df_map.head()
# Out:
#        PlayerFBref                                           UrlFBref  \
# 0   A.J. DeLaGarza  https://fbref.com/en/players/171b3c37/AJ-DeLaG...
# 1      AJ Marcucci  https://fbref.com/en/players/20c86a38/AJ-Marcucci
# 2       Aapo Halme   https://fbref.com/en/players/02b952ce/Aapo-Halme
# 3  Aaron Bastiaans  https://fbref.com/en/players/fb979733/Aaron-Ba...
# 4   Aaron Connolly  https://fbref.com/en/players/27c01749/Aaron-Co...
#
#                                            UrlTmarkt           TmPos
# 0  https://www.transfermarkt.com/a-j-delagarza/pr...      Right-Back
# 1  https://www.transfermarkt.com/aj-marcucci/prof...      Goalkeeper
# 2  https://www.transfermarkt.com/aapo-halme/profi...     Centre-Back
# 3  https://www.transfermarkt.com/aaron-bastiaans/...     Left Winger
# 4  https://www.transfermarkt.com/aaron-connolly/p...  Centre-Forward

# %%
df_map[df_map['PlayerFBref'].str.contains('Mateo', na=False)]
# Out:
#               PlayerFBref                                           UrlFBref  \
# 6104  Jaime Sierra Mateos  https://fbref.com/en/players/aaa4239e/Jaime-Si...
# 9624       Mateo Bajamich  https://fbref.com/en/players/d005b036/Mateo-Ba...
# 9625      Mateo Cassierra  https://fbref.com/en/players/0f714df2/Mateo-Ca...
# 9626         Mateo Joseph  https://fbref.com/en/players/6ad43f9a/Mateo-Jo...
# 9627      Mateo Klimowicz  https://fbref.com/en/players/2b7c56b4/Mateo-Kl...
# 9628      Mateo KovaÄiÄ  https://fbref.com/en/players/79c0821a/Mateo-Ko...
# 9629           Mateo LeÅ¡    https://fbref.com/en/players/5eaad139/Mateo-Les
# 9630      Mateo Musacchio  https://fbref.com/en/players/91899ca8/Mateo-Mu...
# 9631      Mateo PavloviÄ  https://fbref.com/en/players/450e277f/Mateo-Pa...
# 9632        Mateo Retegui  https://fbref.com/en/players/e7695e6c/Mateo-Re...
#
#                                               UrlTmarkt               TmPos
# 6104  https://www.transfermarkt.com/jaime-sierra/pro...    Central Midfield
# 9624  https://www.transfermarkt.com/mateo-bajamich/p...        Right Winger
# 9625  https://www.transfermarkt.com/mateo-cassierra/...      Centre-Forward
# 9626  https://www.transfermarkt.com/mateo-joseph/pro...      Centre-Forward
# 9627  https://www.transfermarkt.com/mateo-klimowicz/...  Attacking Midfield
# 9628  https://www.transfermarkt.com/mateo-kovacic/pr...    Central Midfield
# 9629  https://www.transfermarkt.com/mateo-les/profil...         Centre-Back
# 9630  https://www.transfermarkt.com/mateo-musacchio/...         Centre-Back
# 9631  https://www.transfermarkt.com/mateo-pavlovic/p...         Centre-Back
# 9632  https://www.transfermarkt.com/mateo-retegui/pr...      Centre-Forward

# %%
df_wage_pl = pd.read_csv('players_wage_ranking_PL.csv', encoding="latin1")
j = 50
df_wage_pl.iloc[j:j+20, :]
# Out:
#     Rk               Player   Nation    Pos            Squad  Age  \
# 50  51         Jarrod Bowen  eng ENG  FW,MF         West Ham   27
# 51  52       Lucas PaquetÃ¡   br BRA  MF,FW         West Ham   26
# 52  53  Alexis Mac Allister   ar ARG     MF        Liverpool   25
# 53  54              Alisson   br BRA     GK        Liverpool   31
# 54  55      Federico Chiesa   it ITA     FW        Liverpool   26
# 55  56     Ryan Gravenberch   nl NED     MF        Liverpool   22
# 56  57      Boubacar Kamara   fr FRA     MF      Aston Villa   24
# 57  58   Emiliano MartÃ­nez   ar ARG     GK      Aston Villa   31
# 58  59      Youri Tielemans   be BEL     MF      Aston Villa   27
# 59  60       Anthony Gordon  eng ENG  FW,MF    Newcastle Utd   23
# 60  61            Joelinton   br BRA  MF,FW    Newcastle Utd   27
# 61  62          Lloyd Kelly  eng ENG     DF    Newcastle Utd   25
# 62  63      Mateo KovaÄiÄ   hr CRO     MF  Manchester City   30
# 63  64      MoisÃ©s Caicedo   ec ECU  MF,DF          Chelsea   22
# 64  65        Donyell Malen   nl NED     FW      Aston Villa   25
# 65  66       Darwin NÃºÃ±ez   uy URU     FW        Liverpool   25
# 66  67           Diogo Jota   pt POR     FW        Liverpool   27
# 67  68         Amadou Onana   be BEL     MF      Aston Villa   22
# 68  69          Jamie Vardy  eng ENG     FW   Leicester City   37
# 69  70    Noussair Mazraoui   ma MAR     DF   Manchester Utd   26
#
#                           Weekly Wages  \
# 50  Â£ 150,000 (â¬ 177,712, $183,188)
# 51  Â£ 150,000 (â¬ 177,712, $183,188)
# 52  Â£ 150,000 (â¬ 177,712, $183,188)
# 53  Â£ 150,000 (â¬ 177,712, $183,188)
# 54  Â£ 150,000 (â¬ 177,712, $183,188)
# 55  Â£ 150,000 (â¬ 177,712, $183,188)
# 56  Â£ 150,000 (â¬ 177,712, $183,188)
# 57  Â£ 150,000 (â¬ 177,712, $183,188)
# 58  Â£ 150,000 (â¬ 177,712, $183,188)
# 59  Â£ 150,000 (â¬ 177,712, $183,188)
# 60  Â£ 150,000 (â¬ 177,712, $183,188)
# 61  Â£ 150,000 (â¬ 177,712, $183,188)
# 62  Â£ 150,000 (â¬ 177,712, $183,188)
# 63  Â£ 150,000 (â¬ 177,712, $183,188)
# 64  Â£ 140,000 (â¬ 166,036, $185,838)
# 65  Â£ 140,000 (â¬ 165,865, $170,975)
# 66  Â£ 140,000 (â¬ 165,865, $170,975)
# 67  Â£ 140,000 (â¬ 165,865, $170,975)
# 68  Â£ 140,000 (â¬ 165,865, $170,975)
# 69  Â£ 135,000 (â¬ 159,941, $164,869)
#
#                                 Annual Wages                  Notes
# 50  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 51  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 52  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)  Unverified estimation
# 53  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 54  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 55  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)  Unverified estimation
# 56  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 57  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)  Unverified estimation
# 58  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 59  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)  Unverified estimation
# 60  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)  Unverified estimation
# 61  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 62  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)  Unverified estimation
# 63  Â£ 7,800,000 (â¬ 9,241,027, $9,525,767)                    NaN
# 64  Â£ 7,280,000 (â¬ 8,633,865, $9,663,588)                    NaN
# 65  Â£ 7,280,000 (â¬ 8,624,959, $8,890,716)                    NaN
# 66  Â£ 7,280,000 (â¬ 8,624,959, $8,890,716)                    NaN
# 67  Â£ 7,280,000 (â¬ 8,624,959, $8,890,716)  Unverified estimation
# 68  Â£ 7,280,000 (â¬ 8,624,959, $8,890,716)                    NaN
# 69  Â£ 7,020,000 (â¬ 8,316,925, $8,573,190)  Unverified estimation

# %%
df_wage_pl_url['Weekly Wages'] = df_wage_pl_url['Weekly Wages'].apply(ftfy.fix_text)

# %%
df_wage_pl_url = pd.read_csv('players_wage_ranking_PL_URL.csv', encoding="latin1")
df_wage_pl_url.head()
# Out:
#    Rk           Player  Nation    Pos            Squad  Age  \
# 0   1  Kevin De Bruyne  be BEL  MF,FW  Manchester City   33
# 1   2   Erling Haaland  no NOR     FW  Manchester City   24
# 2   3         Casemiro  br BRA     MF   Manchester Utd   32
# 3   4    Mohamed Salah  eg EGY     FW        Liverpool   32
# 4   5  Bruno Fernandes  pt POR     MF   Manchester Utd   29
#
#                               Weekly Wages  \
# 0  ÃÂ£ 400,000 (Ã¢ÂÂ¬ 473,899, $488,501)
# 1  ÃÂ£ 375,000 (Ã¢ÂÂ¬ 444,280, $457,970)
# 2  ÃÂ£ 350,000 (Ã¢ÂÂ¬ 414,661, $427,438)
# 3  ÃÂ£ 350,000 (Ã¢ÂÂ¬ 414,661, $427,438)
# 4  ÃÂ£ 300,000 (Ã¢ÂÂ¬ 355,424, $366,376)
#
#                                        Annual Wages Notes      PlayerFBref  \
# 0  ÃÂ£ 20,800,000 (Ã¢ÂÂ¬ 24,642,740, $25,402,046)   NaN  Kevin De Bruyne
# 1  ÃÂ£ 19,500,000 (Ã¢ÂÂ¬ 23,102,568, $23,814,418)   NaN   Erling Haaland
# 2  ÃÂ£ 18,200,000 (Ã¢ÂÂ¬ 21,562,397, $22,226,790)   NaN         Casemiro
# 3  ÃÂ£ 18,200,000 (Ã¢ÂÂ¬ 21,562,397, $22,226,790)   NaN    Mohamed Salah
# 4  ÃÂ£ 15,600,000 (Ã¢ÂÂ¬ 18,482,055, $19,051,534)   NaN  Bruno Fernandes
#
#                                             UrlFBref  \
# 0  https://fbref.com/en/players/e46012d4/Kevin-De...
# 1  https://fbref.com/en/players/1f44ac21/Erling-H...
# 2     https://fbref.com/en/players/4d224fe8/Casemiro
# 3  https://fbref.com/en/players/e342ad68/Mohamed-...
# 4  https://fbref.com/en/players/507c7bdf/Bruno-Fe...
#
#                                            UrlTmarkt               TmPos  \
# 0  https://www.transfermarkt.com/kevin-de-bruyne/...  Attacking Midfield
# 1  https://www.transfermarkt.com/erling-haaland/p...      Centre-Forward
# 2  https://www.transfermarkt.com/casemiro/profil/...  Defensive Midfield
# 3  https://www.transfermarkt.com/mohamed-salah/pr...        Right Winger
# 4  https://www.transfermarkt.com/bruno-fernandes/...  Attacking Midfield
#
#                                            24-25_url
# 0  https://fbref.com/en/players/e46012d4/scout/12...
# 1  https://fbref.com/en/players/1f44ac21/scout/12...
# 2  https://fbref.com/en/players/4d224fe8/scout/12...
# 3  https://fbref.com/en/players/e342ad68/scout/12...
# 4  https://fbref.com/en/players/507c7bdf/scout/12...

# %%
df_wage_pl_url[df_wage_pl_url['24-25_url'].isnull()]
# Out:
#       Rk              Player   Nation    Pos           Squad  Age  \
# 161  150      Ferdi Kadioglu   tr TUR  DF,MF        Brighton   24
# 200  188   JÃÂ¡der DurÃÂ¡n   co COL     FW     Aston Villa   20
# 294  275         Igor Thiago      NaN     CF       Brentford   23
# 296  277  Filip JÃÂ¸rgensen   dk DEN     GK         Chelsea   22
# 324  301     Daniel MuÃÂ±oz   co COL     DF  Crystal Palace   28
# ..   ...                 ...      ...    ...             ...  ...
# 715  678    Charlie McArthur      NaN     CB   Newcastle Utd   19
# 718  681       George Abbott      NaN     DM       Tottenham   19
# 719  682       Rico Richards  eng ENG     AM     Aston Villa   21
# 720  683         Kobei Moore      NaN     CF     Aston Villa   20
# 721  684     Luca Stephenson      NaN     DM       Liverpool   21
#
#                                Weekly Wages  \
# 161  ÃÂ£ 87,500 (Ã¢ÂÂ¬ 103,665, $106,860)
# 200    ÃÂ£ 75,000 (Ã¢ÂÂ¬ 88,856, $91,594)
# 294    ÃÂ£ 50,000 (Ã¢ÂÂ¬ 59,237, $61,063)
# 296    ÃÂ£ 50,000 (Ã¢ÂÂ¬ 59,237, $61,063)
# 324    ÃÂ£ 45,000 (Ã¢ÂÂ¬ 53,314, $54,956)
# ..                                      ...
# 715       ÃÂ£ 1,000 (Ã¢ÂÂ¬ 1,186, $1,327)
# 718             ÃÂ£ 750 (Ã¢ÂÂ¬ 889, $996)
# 719             ÃÂ£ 750 (Ã¢ÂÂ¬ 889, $996)
# 720             ÃÂ£ 600 (Ã¢ÂÂ¬ 712, $796)
# 721             ÃÂ£ 400 (Ã¢ÂÂ¬ 474, $531)
#
#                                       Annual Wages                  Notes  \
# 161  ÃÂ£ 4,550,000 (Ã¢ÂÂ¬ 5,390,599, $5,556,698)                    NaN
# 200  ÃÂ£ 3,900,000 (Ã¢ÂÂ¬ 4,620,514, $4,762,884)  Unverified estimation
# 294  ÃÂ£ 2,600,000 (Ã¢ÂÂ¬ 3,080,342, $3,175,256)  Unverified estimation
# 296  ÃÂ£ 2,600,000 (Ã¢ÂÂ¬ 3,080,342, $3,175,256)  Unverified estimation
# 324  ÃÂ£ 2,340,000 (Ã¢ÂÂ¬ 2,772,308, $2,857,730)  Unverified estimation
# ..                                             ...                    ...
# 715           ÃÂ£ 52,000 (Ã¢ÂÂ¬ 61,670, $69,026)  Unverified estimation
# 718           ÃÂ£ 39,000 (Ã¢ÂÂ¬ 46,253, $51,769)  Unverified estimation
# 719           ÃÂ£ 39,000 (Ã¢ÂÂ¬ 46,253, $51,769)  Unverified estimation
# 720           ÃÂ£ 31,200 (Ã¢ÂÂ¬ 37,002, $41,415)  Unverified estimation
# 721           ÃÂ£ 20,800 (Ã¢ÂÂ¬ 24,668, $27,610)  Unverified estimation
#
#     PlayerFBref UrlFBref UrlTmarkt TmPos 24-25_url
# 161         NaN      NaN       NaN   NaN       NaN
# 200         NaN      NaN       NaN   NaN       NaN
# 294         NaN      NaN       NaN   NaN       NaN
# 296         NaN      NaN       NaN   NaN       NaN
# 324         NaN      NaN       NaN   NaN       NaN
# ..          ...      ...       ...   ...       ...
# 715         NaN      NaN       NaN   NaN       NaN
# 718         NaN      NaN       NaN   NaN       NaN
# 719         NaN      NaN       NaN   NaN       NaN
# 720         NaN      NaN       NaN   NaN       NaN
# 721         NaN      NaN       NaN   NaN       NaN
#
# [134 rows x 14 columns]

# %%
player_replace = 'Ilya Zabarnyi'
url_replace = 'https://fbref.com/en/players/88968486/scout/12524/Illia-Zabarnyi-Scouting-Report'
df_wage_pl_url.loc[df_wage_pl_url['Player'] == player_replace, '24-25_url'] = url_replace
df_wage_pl_url[df_wage_pl_url['Player'] == player_replace]
# Out:
#       Rk         Player Nation Pos        Squad  Age  \
# 279  260  Ilya Zabarnyi    NaN  CB  Bournemouth   22
#
#                              Weekly Wages  \
# 279  ÃÂ£ 50,000 (Ã¢ÂÂ¬ 59,237, $61,063)
#
#                                       Annual Wages                  Notes  \
# 279  ÃÂ£ 2,600,000 (Ã¢ÂÂ¬ 3,080,342, $3,175,256)  Unverified estimation
#
#     PlayerFBref UrlFBref UrlTmarkt TmPos  \
# 279         NaN      NaN       NaN   NaN
#
#                                              24-25_url
# 279  https://fbref.com/en/players/88968486/scout/12...

# %%
df_wage_pl_url.to_csv('players_wage_ranking_PL_URL.csv', index=None)

# %%
error_name = 'Manuel Ugarte Ribeiro'
df_map[df_map['PlayerFBref'] == error_name]
# Out:
#                 PlayerFBref  \
# 9194  Manuel Ugarte Ribeiro
#
#                                                UrlFBref  \
# 9194  https://fbref.com/en/players/c9817014/Manuel-U...
#
#                                               UrlTmarkt           TmPos
# 9194  https://www.transfermarkt.com/edu-ribeiro/prof...  Centre-Forward

# %%
error_name = 'Manuel Ugarte'
df_wage_pl_url[df_wage_pl_url['Player'] == error_name]
# Out:
#     Rk         Player Nation Pos           Squad  Age  \
# 91  83  Manuel Ugarte    NaN  DM  Manchester Utd   23
#
#                                Weekly Wages  \
# 91  ÃÂ£ 120,000 (Ã¢ÂÂ¬ 142,170, $146,550)
#
#                                      Annual Wages                  Notes  \
# 91  ÃÂ£ 6,240,000 (Ã¢ÂÂ¬ 7,392,822, $7,620,614)  Unverified estimation
#
#    PlayerFBref UrlFBref UrlTmarkt TmPos 24-25_url
# 91         NaN      NaN       NaN   NaN       NaN

# %% [markdown]
# # wage ranking on Fbref

# %%
# url = 'https://fbref.com/en/comps/9/wages/Premier-League-Wages'
# url = 'https://fbref.com/en/comps/12/wages/La-Liga-Wages'
# url = 'https://fbref.com/en/comps/11/wages/Serie-A-Wages'
# url = 'https://fbref.com/en/comps/20/wages/Bundesliga-Wages'
url = 'https://fbref.com/en/comps/13/wages/Ligue-1-Wages'

tables = pd.read_html(url)
df = tables[1]  # 選手ごとのテーブル
df.head()
# Out:
#    Rk                 Player  Nation Pos      Squad  Age  \
# 0   1        Ousmane Dembélé  fr FRA  FW  Paris S-G   27
# 1   2        Lucas Hernández  fr FRA  DF  Paris S-G   28
# 2   3             Marquinhos  br BRA  CB  Paris S-G   30
# 3   4  Khvicha Kvaratskhelia  ge GEO  FW  Paris S-G   23
# 4   5         Milan Škriniar  sk SVK  DF  Paris S-G   29
#
#                       Weekly Wages                              Annual Wages  \
# 0  € 384,615 (£ 324,645, $396,473)  € 20,000,000 (£ 16,881,526, $20,616,602)
# 1  € 365,385 (£ 308,413, $376,649)  € 19,000,000 (£ 16,037,450, $19,585,772)
# 2  € 323,077 (£ 272,702, $333,037)  € 16,800,000 (£ 14,180,482, $17,317,946)
# 3  € 314,615 (£ 265,281, $352,151)  € 16,360,000 (£ 13,794,619, $18,311,858)
# 4  € 314,615 (£ 265,559, $324,315)  € 16,360,000 (£ 13,809,089, $16,864,380)
#
#                    Notes
# 0                    NaN
# 1                    NaN
# 2  Unverified estimation
# 3                    NaN
# 4                    NaN

# %%
df = pd.read_csv('players_wage_ranking_PL.csv')

# %%
def generate_scouting_url(player_name, mapping_csv_path, league_id='12524'):
    # mapping.csvを読み込む
    df = pd.read_csv(mapping_csv_path, encoding='latin1')

    # PlayerFBref列を小文字に変換して一致する行を検索
    df['PlayerFBref_lower'] = df['PlayerFBref'].str.lower()
    player_name_lower = player_name.lower()

    # 一致する行を取得
    matched_row = df[df['PlayerFBref_lower'] == player_name_lower]

    if matched_row.empty:
        print(f"Player '{player_name}' not found in mapping.csv.")
        return None

    # UrlFBrefからplayer_idとplayer_slugを抽出
    url = matched_row.iloc[0]['UrlFBref']
    try:
        parts = url.strip().split('/')
        player_id = parts[5]
        player_slug = parts[6]
    except IndexError:
        print(f"Invalid UrlFBref format for player '{player_name}'.")
        return None

    # スカウティングレポートのURLを生成
    scouting_url = f"https://fbref.com/en/players/{player_id}/scout/{league_id}/{player_slug}-Scouting-Report"
    return scouting_url

# 使用例
player_name = 'Kevin De Bruyne'
mapping_csv_path = 'fbref_to_tm_mapping.csv'  # mapping.csvのパスを指定
scouting_url = generate_scouting_url(player_name, mapping_csv_path)

if scouting_url:
    print(f"Scouting URL for {player_name}: {scouting_url}")
# Out:
# Scouting URL for Kevin De Bruyne: https://fbref.com/en/players/e46012d4/scout/12524/Kevin-De-Bruyne-Scouting-Report

# %%
# ファイルパスの指定
a_csv_path = 'players_wage_ranking_PL.csv'
mapping_csv_path = 'fbref_to_tm_mapping.csv'

# CSVファイルの読み込み
df_a = pd.read_csv(a_csv_path, encoding='latin1')
df_mapping = pd.read_csv(mapping_csv_path, encoding='latin1')

# Player列とPlayerFBref列を小文字に変換して一致させる
df_a['Player_lower'] = df_a['Player'].str.lower()
df_mapping['PlayerFBref_lower'] = df_mapping['PlayerFBref'].str.lower()

# データフレームのマージ
df_merged = pd.merge(df_a, df_mapping, left_on='Player_lower', right_on='PlayerFBref_lower', how='left')

# UrlFBrefからplayer_idとplayer_slugを抽出し、スカウティングレポートのURLを生成
def extract_url(url):
    try:
        parts = url.strip().split('/')
        player_id = parts[5]
        player_slug = parts[6]
        return f'https://fbref.com/en/players/{player_id}/scout/12524/{player_slug}-Scouting-Report'
    except:
        return None

df_merged['24-25_url'] = df_merged['UrlFBref'].apply(extract_url)

# 不要な列の削除
df_merged.drop(['Player_lower', 'PlayerFBref_lower'], axis=1, inplace=True)

# 結果の保存
df_merged.to_csv('a_with_urls.csv', index=False)

# %% [markdown]
# # Scouting report 2024-2025 on Fbref

# %% [markdown]
# # ループ処理検討（ここから）

# %%
df_list = pd.read_csv('players_wage_ranking_PL_URL.csv', encoding='latin1')

# %%
player_name_list = df_list['Player'].tolist()
sc_url_list = df_list['24-25_url'].tolist()
nation_list = df_list['Nation'].tolist()
team_list = df_list['Squad'].tolist()
postion_list = df_list['Pos'].tolist()
age_list = df_list['Age'].tolist()
n = len(df_list)

# %%
df_all = pd.read_csv('scouting_report_v1.csv')
df_all
# Out:
#                      Player   Nation             Team Position  Age Season  \
# 0           Kevin De Bruyne   be BEL  Manchester City    MF,FW   33  24-25
# 1            Erling Haaland   no NOR  Manchester City       FW   24  24-25
# 2                  Casemiro   br BRA   Manchester Utd       MF   32  24-25
# 3             Mohamed Salah   eg EGY        Liverpool       FW   32  24-25
# 4           Bruno Fernandes   pt POR   Manchester Utd       MF   29  24-25
# 5           Marcus Rashford  eng ENG   Manchester Utd    FW,MF   26  24-25
# 6            Bernardo Silva   pt POR  Manchester City    MF,FW   29  24-25
# 7             Jack Grealish  eng ENG  Manchester City    FW,MF   28  24-25
# 8             Omar Marmoush   eg EGY  Manchester City    FW,MF   25  24-25
# 9               Kai Havertz   de GER          Arsenal    FW,MF   25  24-25
# 10            Gabriel Jesus   br BRA          Arsenal       FW   27  24-25
# 11              Mason Mount  eng ENG   Manchester Utd       MF   25  24-25
# 12              John Stones  eng ENG  Manchester City    DF,MF   30  24-25
# 13              Reece James  eng ENG          Chelsea    DF,MF   24  24-25
# 14              Declan Rice  eng ENG          Arsenal       MF   25  24-25
# 15       Martin ÃÂdegaard   no NOR          Arsenal       MF   25  24-25
# 16  ÃÂ°lkay GÃÂ¼ndoÃÂan   de GER  Manchester City       MF   33  24-25
# 17               Phil Foden  eng ENG  Manchester City    MF,FW   24  24-25
# 18          Virgil van Dijk   nl NED        Liverpool       DF   33  24-25
# 19               Phil Foden  eng ENG  Manchester City    MF,FW   24  24-25
# 20          Virgil van Dijk   nl NED        Liverpool       DF   33  24-25
# 21            Thomas Partey   gh GHA          Arsenal    MF,DF   31  24-25
# 22        JoÃ
# Â¡ko Gvardiol   hr CRO  Manchester City       DF   22  24-25
# 23            Wesley Fofana   fr FRA          Chelsea       DF   23  24-25
# 24              Bukayo Saka  eng ENG          Arsenal    FW,MF   22  24-25
# 25         Matthijs de Ligt   nl NED   Manchester Utd       DF   24  24-25
# 26       Christopher Nkunku   fr FRA          Chelsea       FW   26  24-25
# 27           William Saliba   fr FRA          Arsenal       DF   23  24-25
# 28            Harry Maguire  eng ENG   Manchester Utd       DF   31  24-25
# 29            Son Heung-min   kr KOR        Tottenham       FW   32  24-25
# 30       Gabriel Martinelli   br BRA          Arsenal    FW,MF   23  24-25
# 31   Trent Alexander-Arnold  eng ENG        Liverpool       DF   25  24-25
# 32            Manuel Akanji   ch SUI  Manchester City       DF   29  24-25
# 33            RÃÂºben Dias   pt POR  Manchester City       DF   27  24-25
# 34        Enzo FernÃÂ¡ndez   ar ARG          Chelsea       MF   23  24-25
# 35              Kyle Walker  eng ENG  Manchester City       DF   34  24-25
# 36           Marc Cucurella   es ESP          Chelsea       DF   26  24-25
# 37           James Maddison  eng ENG        Tottenham       MF   27  24-25
# 38          Cristian Romero   ar ARG        Tottenham       DF   26  24-25
# 39              Timo Werner   de GER        Tottenham    FW,MF   28  24-25
# 40         Andrew Robertson  sct SCO        Liverpool       DF   30  24-25
# 41       Bruno GuimarÃÂ£es   br BRA    Newcastle Utd       MF   26  24-25
# 42            Nathan AkÃÂ©   nl NED  Manchester City       DF   29  24-25
# 43               Pedro Neto   pt POR          Chelsea       FW   24  24-25
#
#    League  Goals  Assists  Goals + Assists  ...  Fouls Committed  Fouls Drawn  \
# 0     EPL   0.21     0.37             0.58  ...             0.90         0.95
# 1     EPL   0.72     0.10             0.82  ...             0.79         0.43
# 2     EPL   0.06     0.00             0.06  ...             1.20         1.14
# 3     EPL   0.77     0.48             1.25  ...             0.67         1.04
# 4     EPL   0.24     0.30             0.54  ...             0.95         1.19
# 5     EPL   0.38     0.19             0.57  ...             0.57         0.63
# 6     EPL   0.13     0.13             0.27  ...             0.91         1.08
# 7     EPL   0.12     0.12             0.25  ...             0.62         3.12
# 8     EPL   0.54     0.00             0.54  ...             1.15         1.53
# 9     EPL   0.43     0.14             0.58  ...             1.82         1.10
# 10    EPL   0.44     0.00             0.44  ...             2.07         1.48
# 11    EPL   0.14     0.00             0.14  ...             2.32         1.30
# 12    EPL   0.33     0.00             0.33  ...             0.33         0.33
# 13    EPL   0.08     0.08             0.17  ...             0.68         0.93
# 14    EPL   0.13     0.22             0.35  ...             0.67         0.51
# 15    EPL   0.12     0.31             0.43  ...             0.46         0.89
# 16    EPL   0.04     0.24             0.28  ...             0.61         1.09
# 17    EPL   0.35     0.10             0.46  ...             0.25         1.72
# 18    EPL   0.08     0.03             0.11  ...             0.46         0.35
# 19    EPL   0.35     0.10             0.46  ...             0.25         1.72
# 20    EPL   0.08     0.03             0.11  ...             0.46         0.35
# 21    EPL   0.13     0.06             0.19  ...             1.45         1.00
# 22    EPL   0.14     0.00             0.14  ...             0.44         0.74
# 23    EPL   0.00     0.00             0.00  ...             1.84         1.23
# 24    EPL   0.31     0.52             0.83  ...             0.78         2.03
# 25    EPL   0.08     0.00             0.08  ...             0.68         0.51
# 26    EPL   0.29     0.20             0.49  ...             1.56         1.07
# 27    EPL   0.06     0.00             0.06  ...             0.83         0.50
# 28    EPL   0.05     0.00             0.05  ...             0.92         0.56
# 29    EPL   0.30     0.38             0.68  ...             0.26         1.19
# 30    EPL   0.31     0.16             0.47  ...             0.63         0.83
# 31    EPL   0.11     0.23             0.34  ...             0.42         0.34
# 32    EPL   0.00     0.00             0.00  ...             0.76         0.40
# 33    EPL   0.00     0.00             0.00  ...             0.48         0.32
# 34    EPL   0.18     0.21             0.40  ...             1.59         1.65
# 35    EPL   0.00     0.00             0.00  ...             0.56         0.46
# 36    EPL   0.15     0.03             0.18  ...             1.11         1.14
# 37    EPL   0.45     0.35             0.80  ...             1.59         3.18
# 38    EPL   0.06     0.00             0.06  ...             0.89         0.76
# 39    EPL   0.00     0.52             0.52  ...             0.52         0.87
# 40    EPL   0.00     0.04             0.04  ...             0.40         0.29
# 41    EPL   0.14     0.17             0.30  ...             1.79         2.97
# 42    EPL   0.00     0.00             0.00  ...             0.27         0.00
# 43    EPL   0.16     0.24             0.40  ...             0.83         1.31
#
#     Offsides  Penalty Kicks Won  Penalty Kicks Conceded  Own Goals  \
# 0       0.26               0.00                    0.00       0.00
# 1       0.13               0.00                    0.00       0.00
# 2       0.24               0.00                    0.00       0.00
# 3       0.48               0.00                    0.00       0.00
# 4       0.06               0.00                    0.00       0.00
# 5       0.51               0.00                    0.00       0.00
# 6       0.10               0.00                    0.00       0.00
# 7       0.00               0.00                    0.00       0.00
# 8       0.77               0.08                    0.00       0.00
# 9       0.67               0.00                    0.00       0.00
# 10      1.33               0.00                    0.00       0.00
# 11      0.14               0.00                    0.00       0.00
# 12      0.00               0.00                    0.00       0.00
# 13      0.00               0.00                    0.00       0.00
# 14      0.06               0.00                    0.00       0.00
# 15      0.04               0.00                    0.00       0.00
# 16      0.04               0.04                    0.00       0.00
# 17      0.15               0.00                    0.00       0.00
# 18      0.00               0.00                    0.00       0.00
# 19      0.15               0.00                    0.00       0.00
# 20      0.00               0.00                    0.00       0.00
# 21      0.03               0.00                    0.00       0.00
# 22      0.08               0.00                    0.00       0.00
# 23      0.00               0.00                    0.00       0.00
# 24      0.36               0.05                    0.00       0.00
# 25      0.08               0.00                    0.08       0.00
# 26      0.29               0.00                    0.00       0.00
# 27      0.03               0.00                    0.03       0.00
# 28      0.10               0.00                    0.00       0.00
# 29      0.51               0.04                    0.00       0.00
# 30      0.31               0.00                    0.00       0.00
# 31      0.04               0.00                    0.00       0.00
# 32      0.00               0.00                    0.00       0.00
# 33      0.00               0.00                    0.04       0.04
# 34      0.06               0.00                    0.00       0.00
# 35      0.09               0.00                    0.00       0.00
# 36      0.09               0.00                    0.00       0.00
# 37      0.20               0.00                    0.00       0.00
# 38      0.13               0.00                    0.00       0.00
# 39      0.87               0.00                    0.00       0.00
# 40      0.11               0.00                    0.04       0.04
# 41      0.06               0.00                    0.00       0.00
# 42      0.00               0.00                    0.00       0.00
# 43      0.12               0.00                    0.00       0.00
#
#     Ball Recoveries  Aerials Won  Aerials Lost  % of Aerials Won
# 0              3.38         0.26          0.85             0.238
# 1              1.12         1.88          1.64             0.533
# 2              6.20         2.17          1.14             0.655
# 3              2.70         0.24          0.37             0.391
# 4              6.35         0.66          0.84             0.440
# 5              2.41         0.38          0.95             0.286
# 6              3.61         0.17          0.34             0.333
# 7              3.25         0.12          0.87             0.125
# 8              2.83         0.38          0.84             0.313
# 9              1.97         3.02          3.74             0.447
# 10             4.14         1.33          2.66             0.333
# 11             2.60         0.58          1.16             0.333
# 12             3.61         1.31          0.99             0.571
# 13             5.59         1.95          0.76             0.719
# 14             4.97         1.18          0.80             0.597
# 15             3.75         0.31          0.27             0.533
# 16             4.70         0.57          0.45             0.560
# 17             3.09         0.15          0.46             0.250
# 18             3.11         3.22          1.24             0.721
# 19             3.09         0.15          0.46             0.250
# 20             3.11         3.22          1.24             0.721
# 21             4.44         0.90          0.87             0.509
# 22             3.76         1.48          1.13             0.568
# 23             4.15         2.07          0.92             0.692
# 24             3.64         0.52          1.04             0.333
# 25             2.88         2.46          1.23             0.667
# 26             2.83         1.56          2.15             0.421
# 27             4.56         1.81          1.07             0.629
# 28             3.48         3.28          1.28             0.719
# 29             3.63         0.26          0.51             0.333
# 30             3.07         0.67          1.53             0.304
# 31             5.02         0.11          0.49             0.188
# 32             4.60         1.34          1.47             0.476
# 33             3.09         1.47          1.35             0.521
# 34             4.76         0.43          0.89             0.326
# 35             4.27         0.84          0.65             0.563
# 36             3.92         0.96          1.72             0.360
# 37             3.78         0.25          0.35             0.417
# 38             5.72         2.61          1.72             0.603
# 39             3.14         0.00          0.17             0.000
# 40             3.81         0.25          0.51             0.333
# 41             5.17         0.50          0.52             0.486
# 42             3.19         1.73          1.33             0.565
# 43             3.21         0.44          1.19             0.268
#
# [44 rows x 124 columns]

# %%
player_name_list[56]
# Out:
# 'Jarrod Bowen'

# %%
i = 56
tables = pd.read_html(sc_url_list[i])

# %%
tables
# Out:
# [              Standard Stats
#                     Statistic Per 90 Percentile
#  0          Non-Penalty Goals   0.36       48.0
#  1       npxG: Non-Penalty xG   0.24       12.0
#  2                Shots Total   2.60       50.0
#  3                    Assists   0.24       92.0
#  4   xAG: Exp. Assisted Goals   0.21       83.0
#  5                 npxG + xAG   0.45       39.0
#  6      Shot-Creating Actions   3.42       86.0
#  7                        NaN    NaN        NaN
#  8           Passes Attempted  24.67       70.0
#  9          Pass Completion %  71.7%       57.0
#  10        Progressive Passes   2.75       74.0
#  11       Progressive Carries   3.30       83.0
#  12       Successful Take-Ons   1.33       72.0
#  13         Touches (Att Pen)   5.18       63.0
#  14    Progressive Passes Rec   6.42       74.0
#  15                       NaN    NaN        NaN
#  16                   Tackles   1.24       72.0
#  17             Interceptions   0.48       83.0
#  18                    Blocks   0.67       50.0
#  19                Clearances   0.76       41.0
#  20               Aerials Won   0.36        6.0,
#                Standard Stats
#                     Statistic Per 90 Percentile
#  0          Non-Penalty Goals   0.36       88.0
#  1       npxG: Non-Penalty xG   0.24       62.0
#  2                Shots Total   2.60       75.0
#  3                    Assists   0.24       75.0
#  4   xAG: Exp. Assisted Goals   0.21       65.0
#  5                 npxG + xAG   0.45       64.0
#  6      Shot-Creating Actions   3.42       55.0
#  7                        NaN    NaN        NaN
#  8           Passes Attempted  24.67       11.0
#  9          Pass Completion %  71.7%       25.0
#  10        Progressive Passes   2.75       31.0
#  11       Progressive Carries   3.30       57.0
#  12       Successful Take-Ons   1.33       46.0
#  13         Touches (Att Pen)   5.18       73.0
#  14    Progressive Passes Rec   6.42       49.0
#  15                       NaN    NaN        NaN
#  16                   Tackles   1.24       35.0
#  17             Interceptions   0.48       57.0
#  18                    Blocks   0.67       19.0
#  19                Clearances   0.76       50.0
#  20               Aerials Won   0.36       30.0,
#                Standard Stats
#                     Statistic Per 90 Percentile
#  0          Non-Penalty Goals   0.36       97.0
#  1       npxG: Non-Penalty xG   0.24       91.0
#  2                Shots Total   2.60       94.0
#  3                    Assists   0.24       89.0
#  4   xAG: Exp. Assisted Goals   0.21       84.0
#  5                 npxG + xAG   0.45       91.0
#  6      Shot-Creating Actions   3.42       75.0
#  7                        NaN    NaN        NaN
#  8           Passes Attempted  24.67        1.0
#  9          Pass Completion %  71.7%        2.0
#  10        Progressive Passes   2.75       12.0
#  11       Progressive Carries   3.30       90.0
#  12       Successful Take-Ons   1.33       87.0
#  13         Touches (Att Pen)   5.18       94.0
#  14    Progressive Passes Rec   6.42       89.0
#  15                       NaN    NaN        NaN
#  16                   Tackles   1.24        9.0
#  17             Interceptions   0.48       14.0
#  18                    Blocks   0.67        9.0
#  19                Clearances   0.76       17.0
#  20               Aerials Won   0.36       14.0,
#     Rk              Player  Nation                    Squad  Compare
#  0   1    Leandro Trossard  be BEL                  Arsenal  Compare
#  1   2          João Pedro  br BRA   Brighton & Hove Albion  Compare
#  2   3        Bryan Mbeumo  cm CMR                Brentford  Compare
#  3   4          Pedro Neto  pt POR                  Chelsea  Compare
#  4   5       Matheus Cunha  br BRA  Wolverhampton Wanderers  Compare
#  5   6    Georginio Rutter  fr FRA   Brighton & Hove Albion  Compare
#  6   7  Christopher Nkunku  fr FRA                  Chelsea  Compare
#  7   8      Mohammed Kudus  gh GHA          West Ham United  Compare
#  8   9          Diogo Jota  pt POR                Liverpool  Compare
#  9  10           Luis Díaz  co COL                Liverpool  Compare,
#     Rk              Player   Nation                   Squad  Compare
#  0   1     Marcus Rashford  eng ENG                 2 clubs  Compare
#  1   2     Justin Kluivert   nl NED             Bournemouth  Compare
#  2   3          João Pedro   br BRA  Brighton & Hove Albion  Compare
#  3   4    Leandro Trossard   be BEL                 Arsenal  Compare
#  4   5       Morgan Rogers  eng ENG             Aston Villa  Compare
#  5   6  Gabriel Martinelli   br BRA                 Arsenal  Compare
#  6   7          Cody Gakpo   nl NED               Liverpool  Compare
#  7   8       Harvey Barnes  eng ENG        Newcastle United  Compare
#  8   9        Bryan Mbeumo   cm CMR               Brentford  Compare
#  9  10      Anthony Gordon  eng ENG        Newcastle United  Compare,
#     Rk            Player   Nation                   Squad  Compare
#  0   1    Mohammed Kudus   gh GHA         West Ham United  Compare
#  1   2       Bukayo Saka  eng ENG                 Arsenal  Compare
#  2   3  Dejan Kulusevski   se SWE       Tottenham Hotspur  Compare
#  3   4    Yankuba Minteh   gm GAM  Brighton & Hove Albion  Compare
#  4   5      Kaoru Mitoma   jp JPN  Brighton & Hove Albion  Compare
#  5   6      Matt O'Riley   dk DEN  Brighton & Hove Albion  Compare
#  6   7             Sávio   br BRA         Manchester City  Compare
#  7   8       Jeremy Doku   be BEL         Manchester City  Compare
#  8   9        Phil Foden  eng ENG         Manchester City  Compare
#  9  10    James Maddison  eng ENG       Tottenham Hotspur  Compare,
#           Standard Stats
#                Statistic Per 90 Percentile
#  0                 Goals   0.39         43
#  1               Assists   0.24         92
#  2       Goals + Assists   0.64         70
#  3     Non-Penalty Goals   0.36         48
#  4    Penalty Kicks Made   0.03         72
#  ..                  ...    ...        ...
#  164     Ball Recoveries   3.91         83
#  165                 NaN    NaN        NaN
#  166         Aerials Won   0.36          6
#  167        Aerials Lost   1.45         81
#  168    % of Aerials Won  20.0%          2
#
#  [169 rows x 3 columns],
#           Standard Stats
#                Statistic Per 90 Percentile
#  0                 Goals   0.39         87
#  1               Assists   0.24         75
#  2       Goals + Assists   0.64         86
#  3     Non-Penalty Goals   0.36         88
#  4    Penalty Kicks Made   0.03         85
#  ..                  ...    ...        ...
#  164     Ball Recoveries   3.91         52
#  165                 NaN    NaN        NaN
#  166         Aerials Won   0.36         30
#  167        Aerials Lost   1.45         28
#  168    % of Aerials Won  20.0%         13
#
#  [169 rows x 3 columns],
#           Standard Stats
#                Statistic Per 90 Percentile
#  0                 Goals   0.39         97
#  1               Assists   0.24         89
#  2       Goals + Assists   0.64         98
#  3     Non-Penalty Goals   0.36         97
#  4    Penalty Kicks Made   0.03         94
#  ..                  ...    ...        ...
#  164     Ball Recoveries   3.91         21
#  165                 NaN    NaN        NaN
#  166         Aerials Won   0.36         14
#  167        Aerials Lost   1.45         14
#  168    % of Aerials Won  20.0%          3
#
#  [169 rows x 3 columns]]

# %%
for i, df in enumerate(tables):
    print(f"--- Table {i} ---")
    print(df.shape)           # 行数×列数を表示
    print(df.columns.tolist()) # 列名を表示
    # print(df.head(2))         # 先頭2行だけ表示（全体が大きい場合もOK）
    # print(df.info())          # 型やnull情報などの概要
    print('-' * 40)
# Out:
# --- Table 0 ---
# (21, 3)
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]
# ----------------------------------------
# --- Table 1 ---
# (21, 3)
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]
# ----------------------------------------
# --- Table 2 ---
# (21, 3)
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]
# ----------------------------------------
# --- Table 3 ---
# (10, 5)
# ['Rk', 'Player', 'Nation', 'Squad', 'Compare']
# ----------------------------------------
# --- Table 4 ---
# (10, 5)
# ['Rk', 'Player', 'Nation', 'Squad', 'Compare']
# ----------------------------------------
# --- Table 5 ---
# (10, 5)
# ['Rk', 'Player', 'Nation', 'Squad', 'Compare']
# ----------------------------------------
# --- Table 6 ---
# (169, 3)
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]
# ----------------------------------------
# --- Table 7 ---
# (169, 3)
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]
# ----------------------------------------
# --- Table 8 ---
# (169, 3)
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]
# ----------------------------------------

# %%
tables[6]
# Out:
#          Standard Stats
#               Statistic Per 90 Percentile
# 0                 Goals   0.39         43
# 1               Assists   0.24         92
# 2       Goals + Assists   0.64         70
# 3     Non-Penalty Goals   0.36         48
# 4    Penalty Kicks Made   0.03         72
# ..                  ...    ...        ...
# 164     Ball Recoveries   3.91         83
# 165                 NaN    NaN        NaN
# 166         Aerials Won   0.36          6
# 167        Aerials Lost   1.45         81
# 168    % of Aerials Won  20.0%          2
#
# [169 rows x 3 columns]

# %%
if len(tables) == 3:
    df = tables[2]
elif len(tables) == 6:
    df = tables[4]
elif len(tables) == 9:
    df = tables[6]

# 1. columns名を第2要素で再設定
df.columns = [col[1] for col in df.columns]

# %%
for i in range(74, 100):
    print(player_name_list[i])
# Out:
# Darwin NÃÂºÃÂ±ez
# Diogo Jota
# Amadou Onana
# Jamie Vardy
# Noussair Mazraoui
# Mikel Merino
# Ollie Watkins
# Matheus Nunes
# Cole Palmer
# JoÃÂ£o FÃÂ©lix
# Abdoulaye DoucourÃÂ©
# Bernd Leno
# Danny Ings
# Jordan Pickford
# Riccardo Calafiori
# AndrÃÂ© Onana
# Lisandro MartÃÂ­nez
# Manuel Ugarte
# Victor LindelÃÂ¶f
# Aaron Ramsdale
# Alphonse Areola
# Cody Gakpo
# Dominik Szoboszlai
# John McGinn
# Leon Bailey
# Lucas Digne

# %%
df_all = pd.read_csv('scouting_report_v1.csv')

# for i in range(n):
for i in range(74, 100):
    try:
        tables = pd.read_html(sc_url_list[i])
    except ValueError:
        print(f"No tables found at: {sc_url_list[i]}")
        continue  # データがなければスキップ

    if len(tables) == 3:
        df = tables[2]
    elif len(tables) == 6:
        df = tables[4]
    elif len(tables) == 9:
        df = tables[6]
    else:
        exit()

    # 1. columns名を第2要素で再設定
    df.columns = [col[1] for col in df.columns]

    # 2. 不要な行列を除去（StatisticがNaN または to_removeに含まれるものを一括除去）
    df = df.drop(columns="Percentile")

    to_remove = [
        'Shooting', 'Statistic', 'Passing', 'Pass Types',
        'Goal and Shot Creation', 'Defense', 'Possession', 'Miscellaneous Stats'
    ]
    df = df.dropna(subset=['Statistic'])
    df = df[~df['Statistic'].isin(to_remove)]

    # 3. 'Per 90'列の変換を一括で（無名関数＋pandasのstr操作で高速化も可）
    def convert_stat(val):
        if isinstance(val, str) and val.endswith('%'):
            return float(val.rstrip('%')) / 100
        try:
            return float(val)
        except Exception:
            return pd.NA

    df['Per 90'] = df['Per 90'].map(convert_stat)

    # Statistic列をカラム名、Per 90を値にした1行のDataFrameを作る
    df = pd.DataFrame([df.set_index('Statistic')['Per 90'].to_dict()])

    # 基本情報に関する列を作成
    df['Player'] = player_name_list[i]
    df['Nation'] = nation_list[i]
    df['Team'] = team_list[i]
    df['Position'] = postion_list[i]
    df['Age'] = age_list[i]
    df['Season'] = '24-25'
    df['League'] = 'EPL'

    # 列の順序を整理
    cols = list(df.columns)
    # 先頭や好きな位置に入れたい場合は、↓のように順序を指定
    cols_ordered = ['Player', 'Nation', 'Team', 'Position', 'Age', 'Season', 'League'] + [c for c in cols if c not in ['Player', 'Nation', 'Team', 'Position', 'Age', 'Season', 'League']]
    df = df[cols_ordered]
    df_all = pd.concat([df_all, df], ignore_index=True)
    
    print(f"{i}/{n} completed")

    # 待機時間
    time.sleep(30)
# Out:
# 74/722 completed
# 75/722 completed
# 76/722 completed
# 77/722 completed
# 78/722 completed
# 79/722 completed
# 80/722 completed
# 81/722 completed
# 82/722 completed
# No tables found at: https://fbref.com/en/players/8aafd64f/scout/12524/Joao-Felix-Scouting-Report
# 84/722 completed
# 85/722 completed
# No tables found at: https://fbref.com/en/players/07802f7f/scout/12524/Danny-Ings-Scouting-Report
# 87/722 completed
# 88/722 completed
# 89/722 completed
# 90/722 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 6
#       4 for i in range(74, 100):
#       5     try:
# ----> 6         tables = pd.read_html(sc_url_list[i])
#       7     except ValueError:
#       8         print(f"No tables found at: {sc_url_list[i]}")
#
# File c:\Users\tkaki\.vscode\football_analytics\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File c:\Users\tkaki\.vscode\football_analytics\Lib\site-packages\pandas\io\html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     972 p = parser(
#     973     io,
#     974     compiled_match,
#    (...)    979     storage_options,
#     980 )
#     982 try:
# --> 983     tables = p.parse_tables()
#     984 except ValueError as caught:
#     985     # if `io` is an io-like object, check if it's seekable
#     986     # and try to rewind it before trying the next parser
#     987     if hasattr(io, "seekable") and io.seekable():
#
# File c:\Users\tkaki\.vscode\football_analytics\Lib\site-packages\pandas\io\html.py:249, in _HtmlFrameParser.parse_tables(self)
#     241 def parse_tables(self):
#     242     """
#     243     Parse and return all tables from the DOM.
#     244
#    (...)    247     list of parsed (header, body, footer) tuples from tables.
#     248     """
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File c:\Users\tkaki\.vscode\football_analytics\Lib\site-packages\pandas\io\html.py:791, in _LxmlFrameParser._build_doc(self)
#     788         r = parse(f.handle, parser=parser)
#     789 else:
#     790     # try to parse the input in the simplest way
# --> 791     r = parse(self.io, parser=parser)
#     792 try:
#     793     r = r.getroot()
#
# File c:\Users\tkaki\.vscode\football_analytics\Lib\site-packages\lxml\html\__init__.py:914, in parse(filename_or_url, parser, base_url, **kw)
#     912 if parser is None:
#     913     parser = html_parser
# --> 914 return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#
# File src\\lxml\\etree.pyx:3590, in lxml.etree.parse()
#
# File src\\lxml\\parser.pxi:1981, in lxml.etree._parseDocument()
#
# TypeError: cannot parse from 'float'

# %%
df_all
# Out:
#                   Player   Nation             Team Position  Age Season  \
# 0        Kevin De Bruyne   be BEL  Manchester City    MF,FW   33  24-25
# 1         Erling Haaland   no NOR  Manchester City       FW   24  24-25
# 2               Casemiro   br BRA   Manchester Utd       MF   32  24-25
# 3          Mohamed Salah   eg EGY        Liverpool       FW   32  24-25
# 4        Bruno Fernandes   pt POR   Manchester Utd       MF   29  24-25
# ..                   ...      ...              ...      ...  ...    ...
# 66            Bernd Leno   de GER           Fulham       GK   32  24-25
# 67       Jordan Pickford  eng ENG          Everton       GK   30  24-25
# 68    Riccardo Calafiori   it ITA          Arsenal       DF   22  24-25
# 69        AndrÃÂ© Onana   cm CMR   Manchester Utd       GK   28  24-25
# 70  Lisandro MartÃÂ­nez   ar ARG   Manchester Utd       DF   26  24-25
#
#    League  Goals  Assists  Goals + Assists  ...  Launch %  \
# 0     EPL   0.21     0.37             0.58  ...       NaN
# 1     EPL   0.72     0.10             0.82  ...       NaN
# 2     EPL   0.06     0.00             0.06  ...       NaN
# 3     EPL   0.77     0.48             1.25  ...       NaN
# 4     EPL   0.24     0.30             0.54  ...       NaN
# ..    ...    ...      ...              ...  ...       ...
# 66    EPL    NaN      NaN              NaN  ...     0.227
# 67    EPL    NaN      NaN              NaN  ...     0.488
# 68    EPL   0.18     0.09             0.27  ...       NaN
# 69    EPL    NaN      NaN              NaN  ...     0.297
# 70    EPL   0.10     0.05             0.15  ...       NaN
#
#     Average Pass Length  Goal Kicks  Launch% (Goal Kicks)  \
# 0                   NaN         NaN                   NaN
# 1                   NaN         NaN                   NaN
# 2                   NaN         NaN                   NaN
# 3                   NaN         NaN                   NaN
# 4                   NaN         NaN                   NaN
# ..                  ...         ...                   ...
# 66                 28.9        4.53                 0.512
# 67                 39.7        6.08                 0.628
# 68                  NaN         NaN                   NaN
# 69                 30.3        4.38                 0.658
# 70                  NaN         NaN                   NaN
#
#     Avg. Length of Goal Kicks  Crosses Faced  Crosses Stopped  \
# 0                         NaN            NaN              NaN
# 1                         NaN            NaN              NaN
# 2                         NaN            NaN              NaN
# 3                         NaN            NaN              NaN
# 4                         NaN            NaN              NaN
# ..                        ...            ...              ...
# 66                       41.9          13.34             0.61
# 67                       48.7          14.68             0.82
# 68                        NaN            NaN              NaN
# 69                       47.2          11.74             0.65
# 70                        NaN            NaN              NaN
#
#     Crosses Stopped %  Def. Actions Outside Pen. Area  \
# 0                 NaN                             NaN
# 1                 NaN                             NaN
# 2                 NaN                             NaN
# 3                 NaN                             NaN
# 4                 NaN                             NaN
# ..                ...                             ...
# 66              0.045                            0.87
# 67              0.056                            1.50
# 68                NaN                             NaN
# 69              0.055                            0.68
# 70                NaN                             NaN
#
#     Avg. Distance of Def. Actions
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 66                           13.3
# 67                           15.2
# 68                            NaN
# 69                           11.8
# 70                            NaN
#
# [71 rows x 159 columns]

# %%
df_all['Player'] = df_all['Player'].apply(ftfy.fix_text)

# %%
df_all
# Out:
#                 Player   Nation             Team Position  Age Season League  \
# 0      Kevin De Bruyne   be BEL  Manchester City    MF,FW   33  24-25    EPL
# 1       Erling Haaland   no NOR  Manchester City       FW   24  24-25    EPL
# 2             Casemiro   br BRA   Manchester Utd       MF   32  24-25    EPL
# 3        Mohamed Salah   eg EGY        Liverpool       FW   32  24-25    EPL
# 4      Bruno Fernandes   pt POR   Manchester Utd       MF   29  24-25    EPL
# ..                 ...      ...              ...      ...  ...    ...    ...
# 66          Bernd Leno   de GER           Fulham       GK   32  24-25    EPL
# 67     Jordan Pickford  eng ENG          Everton       GK   30  24-25    EPL
# 68  Riccardo Calafiori   it ITA          Arsenal       DF   22  24-25    EPL
# 69         André Onana   cm CMR   Manchester Utd       GK   28  24-25    EPL
# 70   Lisandro Martínez   ar ARG   Manchester Utd       DF   26  24-25    EPL
#
#     Goals  Assists  Goals + Assists  ...  Launch %  Average Pass Length  \
# 0    0.21     0.37             0.58  ...       NaN                  NaN
# 1    0.72     0.10             0.82  ...       NaN                  NaN
# 2    0.06     0.00             0.06  ...       NaN                  NaN
# 3    0.77     0.48             1.25  ...       NaN                  NaN
# 4    0.24     0.30             0.54  ...       NaN                  NaN
# ..    ...      ...              ...  ...       ...                  ...
# 66    NaN      NaN              NaN  ...     0.227                 28.9
# 67    NaN      NaN              NaN  ...     0.488                 39.7
# 68   0.18     0.09             0.27  ...       NaN                  NaN
# 69    NaN      NaN              NaN  ...     0.297                 30.3
# 70   0.10     0.05             0.15  ...       NaN                  NaN
#
#     Goal Kicks  Launch% (Goal Kicks)  Avg. Length of Goal Kicks  \
# 0          NaN                   NaN                        NaN
# 1          NaN                   NaN                        NaN
# 2          NaN                   NaN                        NaN
# 3          NaN                   NaN                        NaN
# 4          NaN                   NaN                        NaN
# ..         ...                   ...                        ...
# 66        4.53                 0.512                       41.9
# 67        6.08                 0.628                       48.7
# 68         NaN                   NaN                        NaN
# 69        4.38                 0.658                       47.2
# 70         NaN                   NaN                        NaN
#
#     Crosses Faced  Crosses Stopped  Crosses Stopped %  \
# 0             NaN              NaN                NaN
# 1             NaN              NaN                NaN
# 2             NaN              NaN                NaN
# 3             NaN              NaN                NaN
# 4             NaN              NaN                NaN
# ..            ...              ...                ...
# 66          13.34             0.61              0.045
# 67          14.68             0.82              0.056
# 68            NaN              NaN                NaN
# 69          11.74             0.65              0.055
# 70            NaN              NaN                NaN
#
#     Def. Actions Outside Pen. Area  Avg. Distance of Def. Actions
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ..                             ...                            ...
# 66                            0.87                           13.3
# 67                            1.50                           15.2
# 68                             NaN                            NaN
# 69                            0.68                           11.8
# 70                             NaN                            NaN
#
# [71 rows x 159 columns]

# %%
df_all.to_csv('scouting_report_v1.csv', index=None)

# %% [markdown]
# # ループ処理検討（ここまで）

# %%
# mapping.csvより
'https://fbref.com/en/players/16aa3654/Takefusa-Kubo'
# Spain
# 24-25: 12538
# 23-24: 12202
# url = 'https://fbref.com/en/players/16aa3654/scout/12538/Takefusa-Kubo-Scouting-Report'
# url = 'https://fbref.com/en/players/82ec26c1/scout/12538/Lamine-Yamal-Scouting-Report'
# url = 'https://fbref.com/en/players/7111d552/scout/12538/Vinicius-Junior-Scouting-Report'
# url = 'https://fbref.com/en/players/8f5e92a6/scout/12538/Rodrygo-Scouting-Report'
# url = 'https://fbref.com/en/players/3423f250/scout/12538/Raphinha-Scouting-Report'
# url = 'https://fbref.com/en/players/afdc14d7/scout/12538/Nico-Williams-Scouting-Report'
url = 'https://fbref.com/en/players/99127249/scout/12538/Antony-Scouting-Report'
#
# England
# url = 'https://fbref.com/en/players/74618572/scout/12524/Kaoru-Mitoma-Scouting-Report'
# url = 'https://fbref.com/en/players/15b287da/scout/12524/Daichi-Kamada-Scouting-Report'
# url = 'https://fbref.com/en/players/1971591f/scout/12524/Cody-Gakpo-Scouting-Report'
# url = 'https://fbref.com/en/players/48a5a5d6/scout/12524/Gabriel-Martinelli-Scouting-Report'
# url = 'https://fbref.com/en/players/a1d5bd30/scout/12524/Marcus-Rashford-Scouting-Report'
# url = 'https://fbref.com/en/players/bc7dc64d/scout/12524/Bukayo-Saka-Scouting-Report'
# url = 'https://fbref.com/en/players/df3cda47/scout/12524/Dejan-Kulusevski-Scouting-Report'
# url = 'https://fbref.com/en/players/e342ad68/scout/12623/Mohamed-Salah-Scouting-Report'
#
# France
# url = 'https://fbref.com/en/players/f833a830/scout/12545/Takumi-Minamino-Scouting-Report'
#

tables = pd.read_html(url)

for i, df in enumerate(tables):
    print(f"--- Table {i} ---")
    print(df.columns.tolist())
    print()
# Out:
# --- Table 0 ---
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]
#
# --- Table 1 ---
# ['Rk', 'Player', 'Nation', 'Squad', 'Compare']
#
# --- Table 2 ---
# [('Standard Stats', 'Statistic'), ('Standard Stats', 'Per 90'), ('Standard Stats', 'Percentile')]

# %%
df = tables[2]
vertical = 0
df.iloc[vertical:vertical+30]
# Out:
#               Standard Stats
#                    Statistic    Per 90  Percentile
# 0                      Goals      0.29          78
# 1                    Assists      0.15          54
# 2            Goals + Assists      0.44          66
# 3          Non-Penalty Goals      0.29          84
# 4         Penalty Kicks Made      0.00          40
# 5    Penalty Kicks Attempted      0.00          39
# 6               Yellow Cards      0.15          56
# 7                  Red Cards      0.07           4
# 8         xG: Expected Goals      0.20          61
# 9       npxG: Non-Penalty xG      0.20          63
# 10  xAG: Exp. Assisted Goals      0.23          83
# 11                npxG + xAG      0.43          76
# 12                       NaN       NaN         NaN
# 13       Progressive Carries      6.31          97
# 14        Progressive Passes      4.18          67
# 15    Progressive Passes Rec     10.64          90
# 16                  Shooting  Shooting    Shooting
# 17                 Statistic    Per 90  Percentile
# 18                     Goals      0.29          78
# 19               Shots Total      2.93          90
# 20           Shots on Target      1.10          90
# 21         Shots on Target %     37.5%          62
# 22                Goals/Shot      0.10          49
# 23      Goals/Shot on Target      0.27          46
# 24     Average Shot Distance     20.00          28
# 25     Shots from Free Kicks      0.07          69
# 26        Penalty Kicks Made      0.00          40
# 27   Penalty Kicks Attempted      0.00          39
# 28                       NaN       NaN         NaN
# 29        xG: Expected Goals      0.20          61

# %%
df.columns = [col[1] for col in df.columns]
df = df.dropna(subset=['Statistic'])

# Shooting, Statistic, Passing, Pass Types, Goal and Shot Creation, Defense, Possession, Miscellaneous Stats
to_remove = [
    'Shooting', 'Statistic', 'Passing', 'Pass Types',
    'Goal and Shot Creation', 'Defense', 'Possession', 'Miscellaneous Stats'
]

df = df[~df['Statistic'].isin(to_remove)]

def convert_stat(value):
    if isinstance(value, str) and value.endswith('%'):
        return float(value.rstrip('%')) / 100
    try:
        return float(value)
    except:
        return pd.NA  # または np.nan

df['Per 90'] = df['Per 90'].apply(convert_stat).astype(float)

df= df.pivot_table(index=None, columns="Statistic", values="Per 90")
df.columns.name = None
df.index.name = None

# %%
# player_name = input()

from urllib.parse import urlparse

# URLのパスを分解
path = urlparse(url).path  # → '/en/players/afdc14d7/scout/12538/Nico-Williams-Scouting-Report'
segments = path.strip('/').split('/')  # → ['en', 'players', 'afdc14d7', 'scout', '12538', 'Nico-Williams-Scouting-Report']

# 選手名の部分を抽出
report_segment = segments[-1]  # 'Nico-Williams-Scouting-Report'

# 名前だけ取り出す
player_name = report_segment.replace('-Scouting-Report', '').replace('-', ' ')
print(player_name)  # → Nico Williams

df['Player'] = player_name

# 必要に応じて、列の順序を変更
cols = ['Player'] + [col for col in df.columns if col != 'Player']
df = df[cols]
# Out:
# Antony

# %%
df
# Out:
#         Player  % of Aerials Won  % of Dribblers Tackled  Aerials Lost  \
# Per 90  Antony             0.294                    0.35          0.88
#
#         Aerials Won  Assists  Average Shot Distance  Ball Recoveries  Blocks  \
# Per 90         0.37     0.15                   20.0             4.69    0.81
#
#         Carries  ...  Touches (Def Pen)  Touches (Live-Ball)  \
# Per 90     43.2  ...               0.66                64.62
#
#         Touches (Mid 3rd)  Yellow Cards  npxG + xAG  npxG/Shot  \
# Per 90              20.39          0.15        0.43       0.07
#
#         npxG: Non-Penalty xG  xA: Expected Assists  xAG: Exp. Assisted Goals  \
# Per 90                   0.2                  0.19                      0.23
#
#         xG: Expected Goals
# Per 90                 0.2
#
# [1 rows x 118 columns]

# %%
df_org = pd.read_csv('players_scouting_report.csv')
df_org
# Out:
#     Unnamed: 0              Player  % of Aerials Won  % of Dribblers Tackled  \
# 0            0        Kaoru Mitoma             0.481                   0.396
# 1            1       Takefusa Kubo             0.440                   0.432
# 2            2          Cody Gakpo             0.385                   0.500
# 3            3  Gabriel Martinelli             0.306                   0.304
# 4            4     Marcus Rashford             0.286                   0.467
# 5            5         Bukayo Saka             0.321                   0.500
# 6            6    Dejan Kulusevski             0.400                   0.373
# 7            7       Mohamed Salah             0.143                   0.333
# 8            8        Lamine Yamal             0.250                   0.444
# 9            9     Vinicius Junior             0.125                   0.278
# 10          10             Rodrygo             0.304                   0.304
# 11          11            Raphinha             0.643                   0.514
# 12          12       Nico Williams             0.393                   0.323
#
#     Aerials Lost  Aerials Won  Assists  Average Shot Distance  \
# 0           0.96         0.89     0.11                   13.9
# 1           0.60         0.47     0.00                   15.9
# 2           1.21         0.76     0.15                   14.9
# 3           1.44         0.63     0.17                   13.1
# 4           0.95         0.38     0.19                   18.0
# 5           1.05         0.50     0.55                   15.6
# 6           0.57         0.38     0.15                   14.7
# 7           0.67         0.11     0.45                   15.9
# 8           0.10         0.03     0.44                   19.1
# 9           0.28         0.04     0.28                   17.6
# 10          0.75         0.33     0.23                   16.4
# 11          0.17         0.30     0.30                   18.8
# 12          0.80         0.52     0.23                   17.7
#
#     Ball Recoveries  Blocks  ...  Touches (Def Pen)  Touches (Live-Ball)  \
# 0              3.31    1.71  ...               0.53                46.74
# 1              4.62    1.41  ...               0.39                51.08
# 2              3.64    1.06  ...               1.16                41.41
# 3              3.13    0.51  ...               0.68                38.73
# 4              2.41    0.63  ...               0.32                42.15
# 5              3.76    1.22  ...               0.33                50.42
# 6              4.56    1.28  ...               0.90                48.07
# 7              2.90    0.45  ...               0.00                44.00
# 8              3.83    0.40  ...               0.27                64.74
# 9              2.88    0.28  ...               0.16                49.85
# 10             3.31    0.84  ...               0.65                62.55
# 11             2.98    0.90  ...               1.01                58.91
# 12             4.13    0.89  ...               0.38                48.36
#
#     Touches (Mid 3rd)  Yellow Cards  npxG + xAG  npxG/Shot  \
# 0               16.03          0.04        0.47       0.16
# 1               20.34          0.21        0.32       0.09
# 2               12.07          0.25        0.53       0.13
# 3                9.88          0.04        0.47       0.13
# 4               15.63          0.13        0.53       0.12
# 5               11.24          0.17        0.71       0.10
# 6               16.27          0.11        0.39       0.09
# 7               14.29          0.00        0.77       0.12
# 8               20.52          0.10        0.78       0.07
# 9               15.22          0.32        0.65       0.10
# 10              21.66          0.00        0.32       0.07
# 11              20.91          0.13        0.99       0.16
# 12              14.93          0.05        0.34       0.07
#
#     npxG: Non-Penalty xG  xA: Expected Assists  xAG: Exp. Assisted Goals  \
# 0                   0.31                  0.13                      0.16
# 1                   0.15                  0.15                      0.17
# 2                   0.35                  0.16                      0.18
# 3                   0.27                  0.19                      0.20
# 4                   0.25                  0.22                      0.28
# 5                   0.33                  0.39                      0.39
# 6                   0.16                  0.15                      0.23
# 7                   0.38                  0.27                      0.38
# 8                   0.31                  0.38                      0.47
# 9                   0.32                  0.28                      0.32
# 10                  0.18                  0.20                      0.14
# 11                  0.58                  0.32                      0.41
# 12                  0.18                  0.19                      0.16
#
#     xG: Expected Goals
# 0                 0.31
# 1                 0.15
# 2                 0.35
# 3                 0.27
# 4                 0.30
# 5                 0.37
# 6                 0.16
# 7                 0.56
# 8                 0.31
# 9                 0.41
# 10                0.19
# 11                0.64
# 12                0.18
#
# [13 rows x 119 columns]

# %%
df_org = df_org.iloc[:, 1:]

# %%
df_all = pd.concat([df_org, df], ignore_index=True)

# %%
df_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_all
#
# NameError: name 'df_all' is not defined

# %%
df_all.to_csv('players_scouting_report.csv')

# %% [markdown]
# # via API

# %%
import requests

response = requests.post('https://fbrapi.com/generate_api_key')
api_key = response.json()['api_key']
print("API Key:", api_key)
# Out:
# API Key: k956oVTcBGABPylpQxg7dw_VIv1mWT6p6SpS1Il-n0k

# %%
headers
# Out:
# {'X-API-Key': '8zwV4R0uGJ-Ef73pZ6CZO6KpqUz63KNAm6IA0uJPst4'}

# %%
import requests
import time

response = requests.post('https://fbrapi.com/generate_api_key')
api_key = response.json()['api_key']
print("API Key:", api_key)

time.sleep(10)

url = "https://fbrapi.com/player-match-stats"
params = {
    "player_id": "92e7e919",
    "league_id": "9",
    "season_id": "2023-2024"
}
headers = {"X-API-Key": api_key}

response = requests.get(url, params=params, headers=headers)
print(response.json())
# Out:
# API Key: raO-1mzHVhMUvAX8JD4JSHvyk46BP2rc2pb9xFGQH6E
# {'message': 'Unauthorized'}

# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://fbref.com/en/comps/9/stats/Premier-League-Stats'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
player_ids = set()
for a in soup.find_all('a', href=True):
    match = re.match(r'^/en/players/([a-f0-9]{8})/', a['href'])
    if match:
        player_ids.add(match.group(1))

print(f"取得した選手IDの数: {len(player_ids)}")
print(player_ids)
# Out:
# 取得した選手IDの数: 0
# set()
